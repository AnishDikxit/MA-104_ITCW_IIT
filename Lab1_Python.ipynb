# %% [markdown]
# <a href="https://colab.research.google.com/github/AnishDikxit/MA-104_ITCW_IIT/blob/main/Lab1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 Lab 1: Welcome to Python! (The Great Unburdening)
#
# Welcome, Today we are trading curly braces `{}` and semicolons `;` for clean indentation and dynamic typing.
#
# **Your Mission:** Build a "Casino Number Guesser" game in under 15 lines of code.
#
# ### 🛑 The Golden Rules of Python
# 1. **No Semicolons:** Do not put `;` at the end of your lines.
# 2. **Indentation Matters:** Python uses spaces to group code instead of `{ }`. If your indentation is wrong, your code will crash.
# 3. **No Type Declarations:** You don't write `int x = 5`. You just write `x = 5`.

# %%
# WARM-UP: Run this cell by clicking the 'Play' button on the left.
# Notice how we don't need a "public static void main" class!

print("Hello World! I am ready to write some Python.")

# TODO: Create a variable called 'my_name' and assign your name to it.
# Then print a welcome message using that variable.

# %% [markdown]
# ---
# ## 🎲 The 10-Line Casino Challenge
#
# **The Rules:**
# 1. The computer will pick a random number between 1 and 10.
# 2. You have exactly **3 attempts** to guess the number.
# 3. If you guess correctly, the program prints "You win!" and stops.
# 4. If you guess incorrectly, the program tells you if you are "Too high" or "Too low".
# 5. If you run out of attempts, the program prints "Game Over" and reveals the number.
#
# *Hint: `input()` always grabs text (Strings). If you need an integer, you must wrap it in `int()` like this: `guess = int(input("Enter number: "))`*

# %%
import random

# 1. The computer picks a random number between 1 and 10
secret_number = random.randint(1, 10)
print("Welcome to the Casino! I am thinking of a number between 1 and 10.")

# 2. Set up a loop that runs exactly 3 times
# Hint: use 'for attempt in range(3):'
for attempt in range(3):

    # 3. Ask the user for their guess and convert it to an integer
    # TODO: write your input code here


    # 4. Check if the guess is correct
    # TODO: Write an 'if' statement checking if guess == secret_number
        # If true, print "You win!" and use the 'break' keyword to exit the loop


    # 5. Check if the guess is too high
    # TODO: Write an 'elif' statement
        # If true, print "Too high!"


    # 6. Otherwise, it must be too low
    # TODO: Write an 'else' statement
        # Print "Too low!"


# 7. The Loss Condition
# This code runs if the loop finishes without hitting a 'break'
else:
    print(f"Game Over! The secret number was {secret_number}")

# %% [markdown]
# ---
# ## ✅ How to Submit Your Lab
#
# Once your game is working perfectly:
# 1. Go to the top menu and click **File** -> **Save a copy in GitHub**.
# 2. Make sure the Repository is set to **YOUR forked repository**, not the TA's!
# 3. Under **Branch**, type: `lab1/YOUR-ROLL-NUMBER` (e.g., `lab1/21124006`). Colab will create this branch for you.
# 4. Add a commit message like "Finished Casino Game" and click **OK**.
# 5. Go to GitHub and open a **Pull Request** to submit your work!
